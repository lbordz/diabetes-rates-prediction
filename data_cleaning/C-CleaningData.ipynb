# %%
import pandas as pd

# %%
finaldf = pd.read_csv('../data/Finaldf_6.csv', index_col='Unnamed: 0') 
#6 with alcohol info
#Fifth with change in poverty rate
#Second one i adding diabetes increase rates rates
#Third on i added obesity and inactivity levels
#fourth one obesity and diabetes 2009-2010 %, race, rural

# %%
finaldf.head()
# Out:
#   State          County    FIPS  2010:UnemploymentRate  FFRPTH09  \
# 0    AL  Autauga County  1001.0                    8.9  0.554170
# 1    AL  Baldwin County  1003.0                   10.0  0.624282
# 2    AL  Barbour County  1005.0                   12.3  0.759301
# 3    AL     Bibb County  1007.0                   11.4  0.305131
# 4    AL   Blount County  1009.0                    9.8  0.418549
#
#    PCT_LACCESS_POP10  Poverty Rate 2010  Pov_Rate_Change_2000_2010  \
# 0          33.769657          11.551009                   0.059726
# 1          19.318473          13.262972                   0.313166
# 2          20.840972          26.070118                  -0.027234
# 3           4.559753          16.490777                  -0.199477
# 4           2.700840          14.731634                   0.259114
#
#    LI:2010:percent  OB:2010:percent  ...  CEN:2010:WAC  CEN:2010:BAC  \
# 0             29.4             30.5  ...      0.806729      0.183431
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3224 entries, 0 to 3236
# Data columns (total 46 columns):
# State                        3142 non-null object
# County                       3143 non-null object
# FIPS                         3224 non-null float64
# 2010:UnemploymentRate        3214 non-null float64
# FFRPTH09                     3143 non-null float64
# PCT_LACCESS_POP10            3143 non-null float64
# Poverty Rate 2010            3142 non-null float64
# Pov_Rate_Change_2000_2010    3142 non-null float64
# LI:2010:percent              3143 non-null float64
# OB:2010:percent              3143 non-null float64
# OB:2009-2010:Change_rate     3143 non-null float64
# Rural_Pct_2010               3142 non-null float64
# pct_male                     3136 non-null float64
# 2010:AgeGroup01:0-4          3136 non-null float64
# 2010:AgeGroup02:5-9          3136 non-null float64
# 2010:AgeGroup03:10-14        3136 non-null float64
# ...

# %%
#removing county missing names (all Puerto rio basially, not in food environment)
finaldf = finaldf[finaldf['County'].isnull() == False]

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3143 entries, 0 to 3236
# Data columns (total 46 columns):
# State                        3142 non-null object
# County                       3143 non-null object
# FIPS                         3143 non-null float64
# 2010:UnemploymentRate        3136 non-null float64
# FFRPTH09                     3143 non-null float64
# PCT_LACCESS_POP10            3143 non-null float64
# Poverty Rate 2010            3142 non-null float64
# Pov_Rate_Change_2000_2010    3142 non-null float64
# LI:2010:percent              3143 non-null float64
# OB:2010:percent              3143 non-null float64
# OB:2009-2010:Change_rate     3143 non-null float64
# Rural_Pct_2010               3142 non-null float64
# pct_male                     3136 non-null float64
# 2010:AgeGroup01:0-4          3136 non-null float64
# 2010:AgeGroup02:5-9          3136 non-null float64
# 2010:AgeGroup03:10-14        3136 non-null float64
# ...

# %%
finaldf[finaldf['2010:AgeGroup08:35-39'].isnull()][['FIPS', 'State']].groupby('State').size()
# Out:
# State
# AK    4
# HI    1
# SD    1
# dtype: int64

# %%
one_null =  finaldf[finaldf.isnull().sum(axis = 1) > 0]
one_null[one_null['FIPS'] < 72000]
# Out:
#      State                                 County     FIPS  \
# 328     DC                   District of Columbia  11001.0
# 3230    AK                 Petersburg 2009 Census   2195.0
# 3231    AK      Prince of Wales-Hyder 2009 Census   2198.0
# 3232    AK               Wade Hampton Census Area   2270.0
# 3233    AK  Wrangell City and Borough 2009 Census   2275.0
# 3234    HI                         Kalawao County  15005.0
# 3235    SD                         Shannon County  46113.0
# 3236   NaN                           Bedford city  51515.0
#
#       2010:UnemploymentRate  FFRPTH09  PCT_LACCESS_POP10  Poverty Rate 2010  \
# 328                     9.4  1.236010           2.820352                NaN
# 3230                    NaN  0.000000           4.805863          11.644562
# 3231                    NaN  0.000000          25.014925          13.071660
# 3232                    NaN  0.000000          66.430852          29.677935
# ...

# %%
#removing those 6 from the final dataset

# %%
finalfinaldf =  finaldf[finaldf.isnull().sum(axis = 1) == 0]
finalfinaldf.head()
# Out:
#   State          County    FIPS  2010:UnemploymentRate  FFRPTH09  \
# 0    AL  Autauga County  1001.0                    8.9  0.554170
# 1    AL  Baldwin County  1003.0                   10.0  0.624282
# 2    AL  Barbour County  1005.0                   12.3  0.759301
# 3    AL     Bibb County  1007.0                   11.4  0.305131
# 4    AL   Blount County  1009.0                    9.8  0.418549
#
#    PCT_LACCESS_POP10  Poverty Rate 2010  Pov_Rate_Change_2000_2010  \
# 0          33.769657          11.551009                   0.059726
# 1          19.318473          13.262972                   0.313166
# 2          20.840972          26.070118                  -0.027234
# 3           4.559753          16.490777                  -0.199477
# 4           2.700840          14.731634                   0.259114
#
#    LI:2010:percent  OB:2010:percent  ...  CEN:2010:WAC  CEN:2010:BAC  \
# 0             29.4             30.5  ...      0.806729      0.183431
# ...

# %%
finalfinaldf.shape
# Out:
# (3135, 46)

# %%
finalfinaldf[finalfinaldf['Pov_Rate_Change_2000_2010'] > 10]
# Out:
#      State         County     FIPS  2010:UnemploymentRate  FFRPTH09  \
# 2680    TX  Loving County  48301.0                    5.6       0.0
#
#       PCT_LACCESS_POP10  Poverty Rate 2010  Pov_Rate_Change_2000_2010  \
# 2680          99.999999          10.588235                        inf
#
#       LI:2010:percent  OB:2010:percent  ...  CEN:2010:WAC  CEN:2010:BAC  \
# 2680             26.7             29.9  ...       0.95122           0.0
#
#       CEN:2010:IAC  CEN:2010:AAC  CEN:2010:NAC  CEN:2010:H  \
# 2680       0.04878           0.0           0.0    0.219512
#
#       DDP:2010:percent.6  DDP:2009-2010:Growth_Rate  DDP:2012:percent.8  \
# 2680                11.0                   0.122449                11.2
#
#       Diabetes_pct_growth_rate
# 2680                 -0.045455
#
# [1 rows x 46 columns]

# %%
finalfinaldf[finalfinaldf['Pov_Rate_Change_2000_2010'] < 10]['Pov_Rate_Change_2000_2010'].mean()
# Out:
# 0.21438131824306883

# %%
finalfinaldf.loc[2680, "Pov_Rate_Change_2000_2010"] = 0.21438131824306883
# Out:
# /Users/LB/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
finalfinaldf[finalfinaldf['Pov_Rate_Change_2000_2010'] > 10]
# Out:
# Empty DataFrame
# Columns: [State, County, FIPS, 2010:UnemploymentRate, FFRPTH09, PCT_LACCESS_POP10, Poverty Rate 2010, Pov_Rate_Change_2000_2010, LI:2010:percent, OB:2010:percent, OB:2009-2010:Change_rate, Rural_Pct_2010, pct_male, 2010:AgeGroup01:0-4, 2010:AgeGroup02:5-9, 2010:AgeGroup03:10-14, 2010:AgeGroup04:15-19, 2010:AgeGroup05:20-24, 2010:AgeGroup06:25-29, 2010:AgeGroup07:30-34, 2010:AgeGroup08:35-39, 2010:AgeGroup09:40-44, 2010:AgeGroup10:45-49, 2010:AgeGroup11:50-54, 2010:AgeGroup12:55-59, 2010:AgeGroup13:60-64, 2010:AgeGroup14:65-69, 2010:AgeGroup15:70-74, 2010:AgeGroup16:75-79, 2010:AgeGroup17:80-84, 2010:AgeGroup18:85+, CEN:2010:WA, CEN:2010:BA, CEN:2010:IA, CEN:2010:AA, CEN:2010:NA, CEN:2010:WAC, CEN:2010:BAC, CEN:2010:IAC, CEN:2010:AAC, CEN:2010:NAC, CEN:2010:H, DDP:2010:percent.6, DDP:2009-2010:Growth_Rate, DDP:2012:percent.8, Diabetes_pct_growth_rate]
# Index: []
#
# [0 rows x 46 columns]

# %%
finalfinaldf.to_csv('../data/Finaldf_Cleaned_5.csv')  #iwth 10-year change poverty rate
